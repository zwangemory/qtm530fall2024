# %% [markdown]
# # Lecture 2 Exercises

# %% [markdown]
# ## Short Questions
#
# <font size = "5">
#
# 1. How do you check whether an element is part of a list?
# 2. How do you reference a global variable in ```.query()```?

# %%
# Write your answers here as comments:


# 1. the "in" command can help check whether an element is part of a list. 

# 2. to reference a global variable in .query(), researchers can use"@variable_name".

# %% [markdown]
# ## Long Questions

# %% [markdown]
# <font size = "5">
#
# Import the pandas and matplotlib packages

# %%
# Write your own code

import matplotlib.pyplot as plt
import pandas as pd

import numpy as np

# %% [markdown]
# <font size = "5">
#
# (a) Checking a string condition
#
# <font size = "3">
#
# - Define a variable "fruit" with the value "apple"
# - Define a list
#
# list_fruits = ["banana","orange","apple"]
# - Write an expression to test whether "fruit" is contained in "list_fruits"
#
# Hint: Use the "in" command. The final output should be True/False.
#
# To get full points run all of the above commands

# %%
# Write your own code


keyword      = "apple"
list_fruits = ["banana","orange","apple"]

print( keyword in list_fruits)
# Out:
# True

# %% [markdown]
# <font size = "5">
#
# (b) Classifying a variable
#
# <font size = "3">
#
# - Define a new variable "year" an assign the value "2008"
# - Write an if/else statement that does the following
#     - print("Year 2000 or earlier") if the year is less than or equal to  2000.
#     - print("Between 2001 and 2005") if the year is between 2001 and 2005.
#     - print("Year 2006 or later") if the year is after 2005.
#
# To get full points you must do all of the above instructions

# %%
# Write your own code

year = 2008 


if year <= 2000:
    print("Year 2000 or earlier")
elif 2001 < year <= 2005:
    print("Between 2001 and 2005")
else:
    print("Year 2006 or later") # since year can be exhausted, so here we can just use "else"
# Out:
# Year 2006 or later

# %% [markdown]
# <font size = "5">
#
# (c) Split a dataset into subsets
#
# <font size = "3">
#
# - Create ``` list_status = [0,1]```
# - Create ``` list_prob = [0.5, 0.5]```
# - Create a new variable $n = 1000$ with the number of rows of the dataset
# - Use
# ```python
#     np.random.choice(list_status,
#                      size = n,
#                      p = list_prob)
# ```
# $\qquad$ to create a new column called "status" <br>
# $\qquad$ which randomly assigns each row to "0" or "1" <br>
# $\qquad$ with equal probability
# - Use .query() to subset all observations with status == 0.<br>
# store it in a new dataset called "data0"
# - Use .query() to subset all observations with status == 1.<br>
# store it in a new dataset called "data1"

# %%
# Write your own code


#set seed
np.random.seed(100)


list_status = [0,1]
list_prob = [0.5, 0.5]

v_c = np.random.choice(list_status, size = 1000, p= list_prob)
v_c = pd.DataFrame(v_c, columns=['value'])   

v_c_0 = v_c.query("value == 0")
v_c_1 = v_c.query("value == 1")

# %% [markdown]
# <font size = "5">
#
# (d) Classifying a variable
#
# <font size = "3">
#
# - Define a new variable "year" an assign the value "2008"
# - Write an if/else statement that does the following
#     - print("Year 2000 or earlier") if the year is less than or equal to  2000.
#     - print("Between 2001 and 2005") if the year is between 2001 and 2005.
#     - print("Year 2006 or later") if the year is after 2005.
#
# To get full points you must do all of the above instructions

# %%
# Write your own code


year = 2008 


if year <= 2000:
    print("Year 2000 or earlier")
elif 2001 < year <= 2005:
    print("Between 2001 and 2005")
else:
    print("Year 2006 or later")

# %% [markdown]
# <font size = "5">
#
# For questions (e) through (g) mport the dataset <br>
#  "data_raw/fifa23_players_basic.csv"
#
# <font size = "3">
#
# - It's a dataset on professional soccer players
# - Rows correspond to players (18,539)
# - Columns contain attributes of players (32)
# - Try to view the dataset before starting

# %%
# Write your own code


fifa = pd.read_csv("data_raw/fifa23_players_basic.csv")

# %% [markdown]
# <font size = "5">
#
# (e) Create a new dataset subsetting the <br>
# players whose age is less than 20

# %%
# Write your own code


fifa_u20     = fifa.query("Age < 20")

# %% [markdown]
# <font size = "5">
#
# (f) Use queries + global variables
#
# <font size = "3">
#
# - Compute the mean of the column "Value(in Euro)" <br>
# and store it as a variable
# - Subset the players whose value is above the mean value <br>
#   using ".query()"
#
#
# HINT: Remember that there is a special syntax for <br>
# when the column names have spaces (see Lecture 10) <br>
# Reference the column as ``` `Value(in Euro)`    ``` inside .query()

# %%
# Write your own code

ValueAverage = fifa["Value(in Euro)"].mean()

#subset players whose value is above the mean value 

fifa_above_ave = fifa.query(" `Value(in Euro)` > @ValueAverage")

# %% [markdown]
# <font size = "5">
#
# (g) Use sorting + ".iloc[]"
#
# <font size = "3">
#
# - Use ".sort_values()" to order the "Age" column <br>
# from youngest to oldest
# - Get a subset with the 5 youngest players

# %%
# Write your own code


#order by "Age" from youngest to oldest

fifa_ascendingage = fifa.sort_values(by = "Age", ascending = True)

# subset with the 5 youngest players 

fifa_youngest = fifa_ascendingage.iloc[0:5,]
display(fifa_youngest)



# here I have a follow-up question, why select single row follows the sequence starting zero,
# But select range will not? 

display(fifa_ascendingage.iloc[ [4], : ])
# Out:
#             Known As        Full Name  Overall  Potential  Value(in Euro)  \
# 17956     A. Dithmer  Andreas Dithmer       53         76          275000
# 18014      J. Ardila      José Ardila       53         73          250000
# 16084       S. Ngoma      Serge Ngoma       58         82          650000
# 11481      O. Vargas      Obed Vargas       64         81         1500000
# 17591  A. Madaliński  Alan Madaliński       54         68          210000
#
#       Positions Played Best Position    Nationality  \
# 17956               GK            GK        Denmark
# 18014               CM           CAM      Venezuela
# 16084               RW            RM  United States
# 11481        CM,CDM,RM           CAM  United States
# 17591               GK            GK         Poland
#
#                                              Image Link  Age  ...  \
# 17956  https://cdn.sofifa.net/players/269/573/23_60.png   16  ...
# 18014  https://cdn.sofifa.net/players/268/892/23_60.png   16  ...
# 16084  https://cdn.sofifa.net/players/267/796/23_60.png   16  ...
# 11481  https://cdn.sofifa.net/players/263/701/23_60.png   16  ...
# 17591  https://cdn.sofifa.net/players/270/590/23_60.png   16  ...
#
#        Preferred Foot  Weak Foot Rating  Skill Moves  \
# 17956           Right                 2            1
# 18014           Right                 3            2
# 16084           Right                 3            2
# 11481           Right                 3            3
# 17591           Right                 3            1
#
#        International Reputation National Team Name  \
# 17956                         1                  -
# 18014                         1                  -
# 16084                         1                  -
# 11481                         1                  -
# 17591                         1                  -
#
#                   National Team Image Link  National Team Position  \
# 17956  https://cdn.sofifa.net/flags/dk.png                       -
# 18014  https://cdn.sofifa.net/flags/ve.png                       -
# 16084  https://cdn.sofifa.net/flags/us.png                       -
# 11481  https://cdn.sofifa.net/flags/us.png                       -
# 17591  https://cdn.sofifa.net/flags/pl.png                       -
#
#       National Team Jersey Number Attacking Work Rate Defensive Work Rate
# 17956                           -              Medium              Medium
# 18014                           -              Medium              Medium
# 16084                           -                High              Medium
# 11481                           -                High              Medium
# 17591                           -              Medium              Medium
#
# [5 rows x 32 columns]
#             Known As        Full Name  Overall  Potential  Value(in Euro)  \
# 17591  A. Madaliński  Alan Madaliński       54         68          210000
#
#       Positions Played Best Position Nationality  \
# 17591               GK            GK      Poland
#
#                                              Image Link  Age  ...  \
# 17591  https://cdn.sofifa.net/players/270/590/23_60.png   16  ...
#
#        Preferred Foot  Weak Foot Rating  Skill Moves  \
# 17591           Right                 3            1
#
#        International Reputation National Team Name  \
# 17591                         1                  -
#
#                   National Team Image Link  National Team Position  \
# 17591  https://cdn.sofifa.net/flags/pl.png                       -
#
#       National Team Jersey Number Attacking Work Rate Defensive Work Rate
# 17591                           -              Medium              Medium
#
# [1 rows x 32 columns]

# %% [markdown]
# <font size = "5">
# For questions (h)-(j), read "data_raw/wdi_2020.csv" <br>
# This is a dataset of countries from <br>
# the World Development Indicators

# %% [markdown]
# <font size = "5">
#
# (h) Extract sorted elements from a dataset
#
# <font size = "3">
#
# - Sort by "prop_urbanpopulation" in descending order
# - Subset the 5 countries with the highest urban population

# %%
# Write your own code
wdi = pd.read_csv("data_raw/wdi_2020.csv")
#sort by proportion of urban population in descending order 


wdi_descendingpop = wdi.sort_values(by = "prop_urbanpopulation", ascending = False)

#the question is incorrect, can only subset countries with the highest proportion of urban population

wdi_new = wdi_descendingpop.iloc[0:5,]
display(wdi_new)
# Out:
#      year yearcode           countryname countrycode  prop_urbanpopulation
# 212  2020   YR2020             Singapore         SGP                 100.0
# 147  2020   YR2020      Macao SAR, China         MAC                 100.0
# 40   2020   YR2020        Cayman Islands         CYM                 100.0
# 90   2020   YR2020             Gibraltar         GIB                 100.0
# 103  2020   YR2020  Hong Kong SAR, China         HKG                 100.0

# %% [markdown]
# <font size = "5">
#
# (i) Subset elements with query
#
# <font size = "3">
#
# - Compute the median of "prop_urbanpopulation"
# - Use ".query()" to subset countries with <br>
#  "prop_urbanpopulation" above the median

# %%
# Write your own code


urbanmedian = wdi["prop_urbanpopulation"].median()


wdi_above_med = wdi.query(" prop_urbanpopulation > @urbanmedian")

# %% [markdown]
# <font size = "5">
#
# (j) Plot by category
#
# <font size = "3">
#
# - Read "data_raw/wdi_urban.csv"<br>
# This contains data from 1980 and 2020
#
# - Create a list with the unique values of "year"
# - Create a plot with a ...
#     - Histogram of "prop_urbanpopulation" <br>
#     for each year
#     - Set the histogram option ``` alpha = 0.5 ``` for transparency
#     - All the histograms should be overlapping
#     - Create a legend with the list of years
#     - Label the axes and the title
#
# What do we learn from the graph?
#
# HINT: See the example at the end of Lecture 10

# %%
# Write your own code

urban = pd.read_csv("data_raw/wdi_urban.csv")


list_unique_year = pd.unique(urban["year"])


for category in list_unique_year:
    df   = urban.query("year == @category")
    plt.hist(x = df["prop_urbanpopulation"], alpha=0.5)
    
# Add labels and a legends    
plt.title("Histogram of proportion of urban population by year")
plt.xlabel("Proportion of Urban Population")
plt.show()

# %% [markdown]
# # Review of last lecture

# %% [markdown]
# <font size = "5">
#
# (k) Composite operations on arrays
#
# <font size = "3">
#
# - Define $r = 0.04$
# - Define two arrays $A$ and $T$ using "np.array()", assigning the following values
#
# $ a = \begin{pmatrix} a_1 \\ a_2 \\ a_3 \end{pmatrix} =  \begin{pmatrix} 20 \\ 30 \\ 15 \end{pmatrix},
# \qquad  t = \begin{pmatrix} t_1 \\ t_2 \\ t_3 \end{pmatrix} = \begin{pmatrix} 0 \\ 1 \\ 2 \end{pmatrix} $
#
# - Use element-by-element vector operations to compute a new array $M$ of length 3:
#
# $ M = \begin{pmatrix} a_1 / (1+r)^{t_0}  \\ a_2 / (1+r)^{t_1} \\ a_3 / (1+r)^{t_2} \end{pmatrix} $
#
# - Compute the sum of the values of $M$ using "M.sum()"
#
# Note: I am using subscripts to denote the individual elements of $a$ and $t$.
# - In the code just enter the values of $a$ and $t$.
# - To get full points you must do all of the above tasks

# %%
# Write your own code

r = 0.04 

a = np.array([20,30,15])
t = np.array([0,1,2])

#first, conduct the square root calculation 
M_tem = (1+r)**t 

# second step, division 

M = a/M_tem

print(M.sum())
# Out:
# 62.71449704142012
