# %% [markdown]
# # <font color='darkblue'> Accessing Files in Google Drive from Colab <font>
#
# - You need to connect Google Colab to Drive to access files (datasets, images, etc.)
# - Add the following lines of code to the beginnning of every file that you run.

# %% [markdown]
# ## (i) Tell Colab to connect to Google Drive

# %%
# "google.colab" is a library
# you will import the sublibrary "drive" which allows "Colab" to access your files

from google.colab import drive
drive.mount('/content/gdrive',force_remount = True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## (i) Select the subfolder where you want to work in

# %%
# Import the "os" package to manage the directory
# Use the subcommand "chdir" to change the directory
# Enter the folder where you're going to be working in
# The only thing that stays

import os
os.chdir("/content/gdrive/My Drive/emoryqtm151storage/emoryqtm151")
